# %%
# %pip list
# Out:
# Package                                  Version
# ---------------------------------------- ---------------
# absl-py                                  1.4.0
# aiohttp                                  3.8.5
# aiohttp-cors                             0.7.0
# aiorwlock                                1.3.0
# aiosignal                                1.3.1
# ansiwrap                                 0.8.4
# anyio                                    3.7.1
# apache-beam                              2.46.0
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# array-record                             0.4.1
# arrow                                    1.2.3
# asttokens                                2.4.0
# astunparse                               1.6.3
# async-lru                                2.0.4
# async-timeout                            4.0.3
# attrs                                    23.1.0
# Babel                                    2.12.1
# ...
